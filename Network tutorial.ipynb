# %%
import networkx as nx
G = nx.Graph()
print(G)
# Out:
# Graph with 0 nodes and 0 edges

# %%
G.add_node("Singapore")
G.add_node("Tokyo")
G.add_node("San Francisco")

# %%
print(G)
# Out:
# Graph with 3 nodes and 0 edges

# %%
G.add_nodes_from(["Riga","Copenhagen"])
print(G)
# Out:
# Graph with 5 nodes and 0 edges

# %%
G.add_edge("Singapore","San Francisco")
G.add_edge("San Francisco","Tokyo")
G.add_edges_from([("Riga","Copenhagen"),("Copenhagen","Singapore"),("Singapore","Tokyo"),("Riga","San Francisco"),("San Francisco","Singapore"),])
print(G)
# Out:
# Graph with 5 nodes and 6 edges

# %%
nx.draw(G)

# %%
nx.draw(G,with_labels=True)

# %%
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True)

# %%
pos = nx.circular_layout(G)
nx.draw(G,pos,with_labels=True)
nx.draw_networkx_edge_labels(G,pos,edge_labels={("Singapore","Tokyo"):'2 flights daily',("San Francisco","Singapore"):'5 flights daily',},font_color='red')
# Out:
# {('Singapore',
#   'Tokyo'): Text(0.654508476093664, 0.47552828417802706, '2 flights daily'),
#  ('San Francisco',
#   'Singapore'): Text(0.09549147175227024, 0.2938926307527015, '5 flights daily')}

# %%
#---directed graph---
G = nx.DiGraph(directed=True)

# add nodes
G.add_node("Singapore")
G.add_node("San Francisco")
G.add_node("Tokyo")
G.add_nodes_from(["Riga", "Copenhagen"])

# add edges
G.add_edge("Singapore","San Francisco")
G.add_edge("San Francisco","Tokyo")
G.add_edges_from(
    [
        ("Riga","Copenhagen"),
        ("Copenhagen","Singapore"),
        ("Singapore","Tokyo"),
        ("Riga","San Francisco"),
        ("San Francisco","Singapore"),
    ]
)
# set layout
pos = nx.circular_layout(G)

# draw graph
nx.draw(G, pos, with_labels = True)

# draw edge labels
nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels={
        ("Singapore","Tokyo"): '2 flights daily', 
        ("San Francisco","Singapore"): '5 flights daily',
    },
    font_color='red'
)
# Out:
# {('Singapore',
#   'Tokyo'): Text(0.09549147175227024, 0.2938926307527015, '2 flights daily'),
#  ('San Francisco',
#   'Singapore'): Text(0.654508476093664, 0.47552828417802706, '5 flights daily')}
